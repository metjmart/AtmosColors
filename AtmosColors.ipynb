# %%
using AtmosColors, PyPlot;

# %%
PyPlot.ColorMap("bluegie")
# Out:
# ColorMap "bluegie"

# %%
PyPlot.ColorMap("blorg")
# Out:
# ColorMap "blorg"

# %%
PyPlot.ColorMap("blorg2")
# Out:
# ColorMap "blorg2"

# %%
PyPlot.ColorMap("carbone")
# Out:
# ColorMap "carbone"

# %%
PyPlot.ColorMap("carbone2")
# Out:
# ColorMap "carbone2"

# %%
PyPlot.ColorMap("ncl_def")
# Out:
# ColorMap "ncl_def"

# %%
PyPlot.ColorMap("ncl_def2")
# Out:
# ColorMap "ncl_def2"

# %%
PyPlot.ColorMap("ncl_div")
# Out:
# ColorMap "ncl_div"

# %%
PyPlot.ColorMap("pyro")
# Out:
# ColorMap "pyro"

# %%
PyPlot.ColorMap("pyro_div")
# Out:
# ColorMap "pyro_div"

# %%
PyPlot.ColorMap("radar")
# Out:
# ColorMap "radar"

# %%
PyPlot.ColorMap("radar2")
# Out:
# ColorMap "radar2"

# %%
PyPlot.ColorMap("radar3")
# Out:
# ColorMap "radar3"

# %%
PyPlot.ColorMap("ssec")
# Out:
# ColorMap "ssec"

# %%
PyPlot.ColorMap("ssec2")
# Out:
# ColorMap "ssec2"
